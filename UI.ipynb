# %%
npx create-vite@latest forecast-frontend --template react
cd forecast-frontend
npm install axios chart.js react-chartjs-2
# Out:
#   Cell In[9], line 1
#     npx create-vite@latest forecast-frontend --template react
#         ^
# SyntaxError: invalid syntax
